# %%
# importando a biblioteca padrão do python pandas
import pandas as pd

# %%
# abrindo arquivo com o excel
df = pd.read_excel("Dados Excel.xlsx")

# %%
# ler o arquivo
df.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
# veja que ele abriu somenta a primeira aba
df = pd.read_excel("Dados Excel.xlsx", sheet_name = 0)

# %%
# comando para abrir a primeira aba

# %%
df.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
# abrindo a segunda aba
df = pd.read_excel("Dados Excel.xlsx", sheet_name = 1)

# %%
df.head()
# Out:
#    AddressID        AddressLine1  AddressLine2     City  StateProvinceID  \
# 0          1       1970 Napa Ct.           NaN  Bothell               79
# 1          2  9833 Mt. Dias Blv.           NaN  Bothell               79
#
#    PostalCode                                 SpatialLocation  \
# 0       98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1       98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1  32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000

# %%
df.shape
# Out:
# (2, 9)

# %%
# é possível selecionar pelo nome da aba
df = pd.read_excel("Dados Excel.xlsx", sheet_name = "Plan1")

# %%
df = pd.read_excel("Dados Excel.xlsx", sheet_name = "Aba2")

# %%
# Verificando os nomes das abas de um arquivo excel
arquivos_excel = pd.ExcelFile("Dados Excel.xlsx")

# %%
arquivos_excel

# %%
# lendo as abas que o arquivo possui
arquivos_excel.sheet_names
# Out:
# ['Plan1', 'Aba2']

# %%
# usando o comando parse para selecionar as abas
aba1 = arquivos_excel.parse("Plan1")
aba2 = arquivos_excel.parse("Aba2")

# %%
# lendo os dados das abas
aba1.head()
# Out:
#    AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0          1         1970 Napa Ct.          NaN  Bothell               79
# 1          2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2          3  7484 Roundtree Drive          NaN  Bothell               79
# 3          4      9539 Glenside Dr          NaN  Bothell               79
# 4          5         1226 Shoe St.          NaN  Bothell               79
#
#   PostalCode                                 SpatialLocation  \
# 0      98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1      98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2      98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3      98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4      98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# ...

# %%
# lendo os dados das abas
aba2.head()
# Out:
#    AddressID        AddressLine1  AddressLine2     City  StateProvinceID  \
# 0          1       1970 Napa Ct.           NaN  Bothell               79
# 1          2  9833 Mt. Dias Blv.           NaN  Bothell               79
#
#    PostalCode                                 SpatialLocation  \
# 0       98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1       98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
#
#                                 rowguid             ModifiedDate
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1  32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000

# %%
aba1.head(20)
# quantidades de linhas para visualização
# Out:
#     AddressID          AddressLine1 AddressLine2     City  StateProvinceID  \
# 0           1         1970 Napa Ct.          NaN  Bothell               79
# 1           2    9833 Mt. Dias Blv.          NaN  Bothell               79
# 2           3  7484 Roundtree Drive          NaN  Bothell               79
# 3           4      9539 Glenside Dr          NaN  Bothell               79
# 4           5         1226 Shoe St.          NaN  Bothell               79
# 5           6  1399 Firestone Drive          NaN  Bothell               79
# 6           7         5672 Hale Dr.          NaN  Bothell               79
# 7           8    6387 Scenic Avenue          NaN  Bothell               79
# 8           9     8713 Yosemite Ct.          NaN  Bothell               79
# 9          10        250 Race Court          NaN  Bothell               79
# 10         11   1318 Lasalle Street          NaN  Bothell               79
# ...
