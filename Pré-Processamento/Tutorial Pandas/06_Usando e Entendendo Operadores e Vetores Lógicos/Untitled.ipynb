# %%
import pandas as pd

# %%
dados = pd.read_csv("bank.csv", encoding = "UTF-8", sep = ";")

# %%
dados
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# como o pandas realiza operações lógicas no dataframe
dados[dados.marital == "single"].head(20)
# Out:
#     age            job marital  education default  balance housing loan  \
# 2    35     management  single   tertiary      no     1350     yes   no
# 5    35     management  single   tertiary      no      747      no   no
# 13   20        student  single  secondary      no      502      no   no
# 17   37         admin.  single   tertiary      no     2317     yes   no
# 18   25    blue-collar  single    primary      no     -221     yes   no
# 22   44       services  single  secondary      no      106      no   no
# 33   32     management  single   tertiary      no     2536     yes   no
# 39   23       services  single   tertiary      no      363     yes   no
# 40   38     management  single   tertiary      no    11971     yes   no
# 41   36     management  single   tertiary      no      553      no   no
# 44   32     technician  single   tertiary      no     2204     yes   no
# 45   34     management  single   tertiary      no      872     yes   no
# ...

# %%
# usando e/ou
dados[(dados.marital == "single") & (dados.education == "primary")][["age","job"]]
# Out:
#       age           job
# 18     25   blue-collar
# 48     32  entrepreneur
# 87     35   blue-collar
# 99     31    unemployed
# 103    57      services
# ...   ...           ...
# 4267   50      services
# 4302   33   blue-collar
# 4396   41       retired
# 4447   49   blue-collar
# 4457   37   blue-collar
#
# [73 rows x 2 columns]

# %%
# pessoa casada e tenha educação primária ou secundária
# casada e (primario ou secundário)
dados[(dados.marital == "married") & ((dados.education == "primary") | (dados.education == "secondary"))].iloc[3:4,2:6]
# Out:
#    marital  education default  balance
# 7  married  secondary      no      147
