# %% [markdown]
# # Lidando com Arquivos XLSX do Excel

# %% [markdown]
# Foi visto no programa anterior algumas formas de tratar dados em arquivos com extensão **.csv**. Nesse arquivo, vamos trilhar os mesmos passos, só que dessa vez, usando arquivos do tipo **.xlsx**.

# %% [markdown]
# > *O arquivo do Microsoft Excel que possui a extensão .XLSX ou .XLS é uma planilha.*

# %%
# importando a biblioteca padrão do Python pandas
import pandas as pd

# %% [markdown]
# Vamos adicionar a uma variável do tipo objeto os dados do arquivo excel.

# %%
dataframe = pd.read_excel("Enderecos DataFrame.xlsx")
# atribuindo a uma variável do tipo objeto para armazenar os dados do documento com extensão .xlsx, usando 
# a função "read_excel", cujo parámetro é a localização no diretório da máquina onde o arquivo está 
# localizado.

# %% [markdown]
# Observe que a variável "**dataframe**" já contém os dados do arquivo.

# %%
dataframe.head(20)
# usando o atributo "head" da biblioteca "Pandas" para visualizar os dados dos 20 primeiros usuários do 
# dataframe
# Out:
#     EnderecoID      EnderecoPrimario EnderecoSecundario   Cidade  ProvinciaID  \
# 0            1         1970 Napa Ct.                NaN  Bothell           79
# 1            2    9833 Mt. Dias Blv.                NaN  Bothell           79
# 2            3  7484 Roundtree Drive                NaN  Bothell           79
# 3            4      9539 Glenside Dr                NaN  Bothell           79
# 4            5         1226 Shoe St.                NaN  Bothell           79
# 5            6  1399 Firestone Drive                NaN  Bothell           79
# 6            7         5672 Hale Dr.                NaN  Bothell           79
# 7            8    6387 Scenic Avenue                NaN  Bothell           79
# 8            9     8713 Yosemite Ct.                NaN  Bothell           79
# 9           10        250 Race Court                NaN  Bothell           79
# 10          11   1318 Lasalle Street                NaN  Bothell           79
# 11          12  5415 San Gabriel Dr.                NaN  Bothell           79
# 12          13           9265 La Paz                NaN  Bothell           79
# 13          14          8157 W. Book                NaN  Bothell           79
# 14          15        4912 La Vuelta                NaN  Bothell           79
# 15          16          40 Ellis St.                NaN  Bothell           79
# 16          17     6696 Anchor Drive                NaN  Bothell           79
# 17          18      1873 Lion Circle                NaN  Bothell           79
# 18          19      3148 Rose Street                NaN  Bothell           79
# 19          20    6872 Thornwood Dr.                NaN  Bothell           79
#
#    CodigoPostal                             LocalizacaoEspacial  \
# 0         98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1         98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2         98011  0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3         98011  0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4         98011  0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
# 5         98011  0xE6100000010CE0B4E50458DA47402F12A5F80C975EC0
# 6         98011  0xE6100000010C18E304C4ADE1474011A5C28A7C955EC0
# 7         98011  0xE6100000010C0029A5D93BDF4740E248962FD5975EC0
# 8         98011  0xE6100000010C6A80AD742DDC4740851574F7198C5EC0
# 9         98011  0xE6100000010C219D64AE1FE4474040862564B7825EC0
# 10        98011  0xE6100000010CCEFFBBFD9FE9474057B9479C728E5EC0
# 11        98011  0xE6100000010C6A80AD742DDC474011A5C28A7C955EC0
# 12        98011  0xE6100000010CC3228C0867E84740F3BC169B7F835EC0
# 13        98011  0xE6100000010C219D64AE1FE4474067A89189898A5EC0
# 14        98011  0xE6100000010C219D64AE1FE447405E6ED153B4945EC0
# 15        98011  0xE6100000010CF76E45EFC9DC474067A89189898A5EC0
# 16        98011  0xE6100000010C034C75E402DE4740BC262A0A03905EC0
# 17        98011  0xE6100000010C219D64AE1FE447405FF307D247845EC0
# 18        98011  0xE6100000010C813A0D5F9FDE47407DDBB3C144965EC0
# 19        98011  0xE6100000010C034C75E402DE4740483BAF1BF9885EC0
#
#                              GuiaDeLinha           DataModificada
# 0   9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1   32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000
# 2   4C506923-6D1B-452C-A07C-BAA6F5B142A4  2013-03-07 00:00:00.000
# 3   E5946C78-4BCC-477F-9FA1-CC09DE16A880  2009-02-03 00:00:00.000
# 4   FBAFF937-4A97-4AF0-81FD-B849900E9BB0  2008-12-19 00:00:00.000
# 5   FEBF8191-9804-44C8-877A-33FDE94F0075  2009-02-13 00:00:00.000
# 6   0175A174-6C34-4D41-B3C1-4419CD6A0446  2009-12-11 00:00:00.000
# 7   3715E813-4DCA-49E0-8F1C-31857D21F269  2008-12-17 00:00:00.000
# 8   268AF621-76D7-4C78-9441-144FD139821A  2012-05-30 00:00:00.000
# 9   0B6B739D-8EB6-4378-8D55-FE196AF34C04  2008-12-02 00:00:00.000
# 10  981B3303-ACA2-49C7-9A96-FB670785B269  2013-02-28 00:00:00.000
# 11  1C2C9CFE-AB9F-4F96-8E1F-D9666B6F7F22  2013-01-05 00:00:00.000
# 12  E0BA2F52-C907-4553-A0DB-67FC67D28AE4  2013-12-14 00:00:00.000
# 13  A1C658AE-C553-4A9D-A081-A550D39B64DF  2009-12-04 00:00:00.000
# 14  F397E64A-A9D8-4E57-9E7C-B10928ACADD6  2013-11-18 00:00:00.000
# 15  0312B65F-CB60-4396-9EC7-A78B2EAC1A1B  2012-11-09 00:00:00.000
# 16  CE9B3B47-9267-4727-BCD2-687C47482C06  2013-11-08 00:00:00.000
# 17  963854F7-E3CB-46A1-A3DB-1B05F71D6473  2013-11-30 00:00:00.000
# 18  6B7ACB0F-CDBF-44FD-BA14-EB08A56C1582  2014-04-03 00:00:00.000
# 19  4B1F1ED4-97A4-43FD-BB1E-9E05817718E8  2009-02-05 00:00:00.000

# %% [markdown]
# Veja a quantidade de linhas e colunas dos dados.

# %%
dataframe.shape
# Usando o atributo "shape" do Python para verificar as dimensões do vetor multidimensional "dataframe".
# Out:
# (1000, 9)

# %% [markdown]
# Como estamos trabalhando com arquivos no excel, podemos ter diferentes abas nele. Por padrão, é aberta somente a primeria aba, essa que é representada pelo inteiro == 0. No documento anexado, há duas abas disponíveis, veja como você pode adicionar os dados da segunda aba a variável "dataframe".

# %%
dataframe = pd.read_excel("Enderecos DataFrame.xlsx", sheet_name = 1)
# Usando a função "read_excel" da biblioteca "Pandas" para adicionar os dados do arquivo "Enderecos 
# Dataframe.xlsx" a variável do tipo objeto "dataframe". O método "sheet_name" recebe o atributo do tipo
# inteiro == 1, esse que significa os dados contidos na segunda aba do excel. Da mesma forma, poderiamos 
# abrir a primeria aba que é padrão usando: sheet_name = 0.

# %% [markdown]
# Observe que agora os dados são relativos a segunda aba.

# %%
dataframe.head()
# Usando o atributo "head" da biblioteca "Pandas" para visualizar os primeiros dados armazenados na 
# variável do tipo objeto "dataframe"
# Out:
#    EnderecoID    EnderecoPrimario  EnderecoSecundario   Cidade  provinciaID  \
# 0           1       1970 Napa Ct.                 NaN  Bothell           79
# 1           2  9833 Mt. Dias Blv.                 NaN  Bothell           79
#
#    CodigoPostal                             LocalizacaoEspacial  \
# 0         98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1         98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
#
#                             GuiaDeLinha           DataModificada
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1  32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000

# %% [markdown]
# Observe que os dados são diferentes, podemos tirar essa prova usando olhando a quantidade de linhas e colunas armazenadas nele.

# %%
dataframe.shape
# Usando o atributo "shape" do Python para visualizar as dimensões do vetor multidimensional que está arma-
# zenado na variável do tipo objeto "dataframe".
# Out:
# (2, 9)

# %% [markdown]
# A mesma seleção pode ser feita se, ao invés de usar como atributo no método "**sheet_name**" um inteiro, usasse uma string com o exato nome da aba.

# %%
dataframe = pd.read_excel("Enderecos DataFrame.xlsx", sheet_name = "Aba1")
# Usando a função "read_excel" do "Pandas" para atribuir a variável do tipo objeto "dataframe" os dados 
# do arquivo "Enderecos DataFrame.xlsx", em que o método "sheet_name" pode receber como atributo uma string
# localizando o nome exato da aba que queremos fazer essa atribuição.

# %%
dataframe
# imprimindo na saída de dados as informações contidas na variável do tipo objeto "dataframe"
# Out:
#      EnderecoID             EnderecoPrimario EnderecoSecundario  \
# 0             1                1970 Napa Ct.                NaN
# 1             2           9833 Mt. Dias Blv.                NaN
# 2             3         7484 Roundtree Drive                NaN
# 3             4             9539 Glenside Dr                NaN
# 4             5                1226 Shoe St.                NaN
# ..          ...                          ...                ...
# 995         996         2575 West 2700 South                NaN
# 996         997     70259 West Sunnyview Ave                NaN
# 997         998           60750 San Clemente                NaN
# 998         999                    Receiving                NaN
# 999        1000  22555 Paseo De Las Americas                NaN
#
#              Cidade  ProvinciaID CodigoPostal  \
# 0           Bothell           79        98011
# 1           Bothell           79        98011
# 2           Bothell           79        98011
# 3           Bothell           79        98011
# 4           Bothell           79        98011
# ..              ...          ...          ...
# 995  Salt Lake City           74        84101
# 996         Visalia            9        93291
# 997         Hayward            9        94541
# 998       Fullerton            9        92831
# 999       San Diego            9        92102
#
#                                 LocalizacaoEspacial  \
# 0    0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1    0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2    0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3    0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4    0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
# ..                                              ...
# 995  0xE6100000010C6E9ADC36AF544440AC180B5B4CF85BC0
# 996  0xE6100000010C4497C3A5F12542406CD48C5685D35DC0
# 997  0xE6100000010CB2747D1801C94240124DA15E0D885EC0
# 998  0xE6100000010C47CB4845F2EA404079A10C358C7F5DC0
# 999  0xE6100000010CA43F3589854540402D8AD214E8385DC0
#
#                               GuiaDeLinha           DataModificada
# 0    9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1    32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000
# 2    4C506923-6D1B-452C-A07C-BAA6F5B142A4  2013-03-07 00:00:00.000
# 3    E5946C78-4BCC-477F-9FA1-CC09DE16A880  2009-02-03 00:00:00.000
# 4    FBAFF937-4A97-4AF0-81FD-B849900E9BB0  2008-12-19 00:00:00.000
# ..                                    ...                      ...
# 995  708FC1DD-4994-4AA5-80A5-8C977C37AA15  2012-06-30 00:00:00.000
# 996  7C2E0511-DE61-4761-80EA-6A7B2F39E524  2013-07-31 00:00:00.000
# 997  822DC2BE-AAC2-4283-93A6-5027CFB6A7DF  2013-07-31 00:00:00.000
# 998  93D3C32F-CC26-4F27-B91F-35A804554976  2012-07-31 00:00:00.000
# 999  982BDCC2-6429-4725-A6DF-4FAF032EC908  2012-06-30 00:00:00.000
#
# [1000 rows x 9 columns]

# %% [markdown]
# E assim a primeira aba foi escolhinda. Vale a pena ressaltar que poderiamos obter o mesmo resultado usando "sheet_name" = 0.

# %% [markdown]
# Vamos selecionar a segunda aba usando uma entrada em "sheet_name" no formato string.

# %%
dataframe = pd.read_excel("Enderecos DataFrame.xlsx", sheet_name = "Aba2")
# Usando a função "read_excel" do "Pandas" para atribuir a variável do tipo objeto "dataframe" os dados 
# do arquivo "Enderecos DataFrame.xlsx", em que o método "sheet_name" pode receber como atributo uma string
# localizando o nome exato da aba que queremos fazer essa atribuição.

# %%
dataframe
# imprimindo na saída de dados as informações contidas na variável do tipo objeto "dataframe"
# Out:
#    EnderecoID    EnderecoPrimario  EnderecoSecundario   Cidade  provinciaID  \
# 0           1       1970 Napa Ct.                 NaN  Bothell           79
# 1           2  9833 Mt. Dias Blv.                 NaN  Bothell           79
#
#    CodigoPostal                             LocalizacaoEspacial  \
# 0         98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1         98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
#
#                             GuiaDeLinha           DataModificada
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1  32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000

# %% [markdown]
# Caso você queira saber o nome das abas, use a função "ExcelFile" atribuida a uma variável, essa que será do tipo objeto após a atribuição.

# %%
arquivos_excel = pd.ExcelFile("Enderecos DataFrame.xlsx")
# Usando a função "ExcelFile" para extrair em strings o nome das abas contidas no documento 
# "Enderecos DataFrame.xlsx".

# %% [markdown]
# Observe que não visualizamos os nome das abas quando colocamos "arquivos_excel" na saída de dados, pois ela é um objeto e, dessa forma, visualizamos somente as propiedades do objeto.

# %%
arquivos_excel
# visualizando as propiedades do objeto

# %% [markdown]
# Para visualizar o nome das aba contidas no documento excel, usamos o atributo "**sheet_names**" no objeto.

# %%
arquivos_excel.sheet_names
# Devemos usar o atributo "sheet_names" da biblioteca "Pandas" para visualizar a lista de strings com os 
# relativos nomes das abas.
# Out:
# ['Aba1', 'Aba2']

# %% [markdown]
# Além do método "sheet_name" da função "read_excel" para passar os dados relativos a uma determinada aba do arquivo Excel a uma variável do tipo objeto, temos também o atributo "parse" que cumpre o mesmo objetivo. Observe isso nos códigos abaixo.

# %%
# usando o atributo "parse" da biblioteca "Pandas" para selecionar as abas de um arquivo do excel
aba1 = arquivos_excel.parse("Aba1")
aba2 = arquivos_excel.parse("Aba2")

# %% [markdown]
# Observe agora que o objeto "aba1" armazena os dados relativos a primeira aba usada no documento excel.

# %%
aba1
# Saída de dados para as informações da variável do tipo objeto "aba1".
# Out:
#      EnderecoID             EnderecoPrimario EnderecoSecundario  \
# 0             1                1970 Napa Ct.                NaN
# 1             2           9833 Mt. Dias Blv.                NaN
# 2             3         7484 Roundtree Drive                NaN
# 3             4             9539 Glenside Dr                NaN
# 4             5                1226 Shoe St.                NaN
# ..          ...                          ...                ...
# 995         996         2575 West 2700 South                NaN
# 996         997     70259 West Sunnyview Ave                NaN
# 997         998           60750 San Clemente                NaN
# 998         999                    Receiving                NaN
# 999        1000  22555 Paseo De Las Americas                NaN
#
#              Cidade  ProvinciaID CodigoPostal  \
# 0           Bothell           79        98011
# 1           Bothell           79        98011
# 2           Bothell           79        98011
# 3           Bothell           79        98011
# 4           Bothell           79        98011
# ..              ...          ...          ...
# 995  Salt Lake City           74        84101
# 996         Visalia            9        93291
# 997         Hayward            9        94541
# 998       Fullerton            9        92831
# 999       San Diego            9        92102
#
#                                 LocalizacaoEspacial  \
# 0    0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1    0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
# 2    0xE6100000010C18E304C4ADE14740DA930C7893915EC0
# 3    0xE6100000010C813A0D5F9FDE474011A5C28A7C955EC0
# 4    0xE6100000010C61C64D8ABBD94740C460EA3FD8855EC0
# ..                                              ...
# 995  0xE6100000010C6E9ADC36AF544440AC180B5B4CF85BC0
# 996  0xE6100000010C4497C3A5F12542406CD48C5685D35DC0
# 997  0xE6100000010CB2747D1801C94240124DA15E0D885EC0
# 998  0xE6100000010C47CB4845F2EA404079A10C358C7F5DC0
# 999  0xE6100000010CA43F3589854540402D8AD214E8385DC0
#
#                               GuiaDeLinha           DataModificada
# 0    9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1    32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000
# 2    4C506923-6D1B-452C-A07C-BAA6F5B142A4  2013-03-07 00:00:00.000
# 3    E5946C78-4BCC-477F-9FA1-CC09DE16A880  2009-02-03 00:00:00.000
# 4    FBAFF937-4A97-4AF0-81FD-B849900E9BB0  2008-12-19 00:00:00.000
# ..                                    ...                      ...
# 995  708FC1DD-4994-4AA5-80A5-8C977C37AA15  2012-06-30 00:00:00.000
# 996  7C2E0511-DE61-4761-80EA-6A7B2F39E524  2013-07-31 00:00:00.000
# 997  822DC2BE-AAC2-4283-93A6-5027CFB6A7DF  2013-07-31 00:00:00.000
# 998  93D3C32F-CC26-4F27-B91F-35A804554976  2012-07-31 00:00:00.000
# 999  982BDCC2-6429-4725-A6DF-4FAF032EC908  2012-06-30 00:00:00.000
#
# [1000 rows x 9 columns]

# %% [markdown]
# Observe agora que o objeto "aba2" armazena os dados relativos a segunda aba usada no documento excel.

# %%
aba2
# Saída de dados para as informações da variável do tipo objeto "aba2".
# Out:
#    EnderecoID    EnderecoPrimario  EnderecoSecundario   Cidade  provinciaID  \
# 0           1       1970 Napa Ct.                 NaN  Bothell           79
# 1           2  9833 Mt. Dias Blv.                 NaN  Bothell           79
#
#    CodigoPostal                             LocalizacaoEspacial  \
# 0         98011  0xE6100000010CAE8BFC28BCE4474067A89189898A5EC0
# 1         98011  0xE6100000010CD6FA851AE6D74740BC262A0A03905EC0
#
#                             GuiaDeLinha           DataModificada
# 0  9AADCB0D-36CF-483F-84D8-585C2D4EC6E9  2007-12-04 00:00:00.000
# 1  32A54B9E-E034-4BFB-B573-A71CDE60D8C0  2008-11-30 00:00:00.000

# %% [markdown]
# Desse modo, podemos usar alguns mecanismos da biblioteca "Pandas" do Python para fazer o pré-processamento de dados, tanto em documentos com extensão .csv quanto documentos com extensão .xlsx.

# %% [markdown]
# ### Alguma Dúvida? Entre em Contato Comigo:

# %% [markdown]
# - [Me Envie um E-mail](mailto:alyssonmachado388@gmail.com);
