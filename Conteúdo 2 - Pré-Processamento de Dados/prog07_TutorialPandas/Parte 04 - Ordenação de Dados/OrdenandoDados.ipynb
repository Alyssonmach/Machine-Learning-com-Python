# %% [markdown]
# # Ordenando Dados

# %% [markdown]
# Nesse arquivo, vamos trabalhar com ordenação de dados usando a biblioteca "Pandas" do Python. Com isso, enriquecemos mais nossos conhecimentos em pré-processamento de dados usando essa linguagem de programação.

# %%
import pandas as pd
# importando a biblioteca Pandas do python

# %%
dados = pd.read_excel("Dados.xlsx")
# atribuindo ao objeto "dados" o banco de dados armazenado no arquivo "Dados.xlsx"

# %%
dados
# visualizando os dados continudos no objeto
# Out:
#      BusinessEntityID PersonType  NameStyle Title  FirstName MiddleName  \
# 0                   1         EM          0   NaN        Ken          J
# 1                   2         EM          0   NaN      Terri        Lee
# 2                   3         EM          0   NaN    Roberto        NaN
# 3                   4         EM          0   NaN        Rob        NaN
# 4                   5         EM          0   Ms.       Gail          A
# ..                ...        ...        ...   ...        ...        ...
# 995              1700         IN          0   Ms.    Rebecca         A.
# 996              1701         IN          0   Ms.    Dorothy         B.
# 997              1702         IN          0   Ms.  Carol Ann         F.
# 998              1703         IN          0   Mr.      Scott         M.
# 999              1704         IN          0   Mr.        Jim        NaN
#
#        LastName Suffix  EmailPromotion
# 0       Sánchez    NaN               0
# 1         Duffy    NaN               1
# 2    Tamburello    NaN               0
# 3       Walters    NaN               0
# 4      Erickson    NaN               0
# ..          ...    ...             ...
# 995    Robinson    NaN               0
# 996    Robinson    NaN               2
# 997      Rockne    NaN               0
# 998     Rodgers    NaN               0
# 999      Rodman    NaN               0
#
# [1000 rows x 9 columns]

# %% [markdown]
# Observe que os dados originais estão seguindo a ordenação numérica dos índices. Com o atributo "**sort_values**", podemos escolher outras colunas como referência para ordenação ou até multiplas colunas com ordem de preferência, sejam elas com tipos de variáveis numéricas ou categóricas.

# %%
dados.sort_values("FirstName")
# usando o atributo "sort_values" para ordenar a sequência de usuários através da coluna informada na 
# entrada de dados. No exemplo acima, a ordenação será feita com base no campo de dados "FirstName"
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
# ..                ...        ...        ...   ...       ...        ...
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# 216               217         EM          0   NaN    Zainal          T
# 101               102         EM          0   NaN     Zheng          W
# 901              1513         VC          0   Mr.     Zheng        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1
# ..        ...    ...             ...
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# 216    Arifin    NaN               1
# 101        Mu    NaN               0
# 901        Mu    NaN               0
#
# [1000 rows x 9 columns]

# %%
dados.sort_values("FirstName").head(50)
# usando o atributo "head" para visualizar a ordenação com "sort_values" referenciado pelo campo de dados
# sort_values
# Out:
#      BusinessEntityID PersonType  NameStyle Title  FirstName MiddleName  \
# 797              1305         SC          0   NaN         A.  Francesca
# 221               222         EM          0   NaN   A. Scott        NaN
# 508               727         SC          0   Mr.      Aaron        NaN
# 632               975         SC          0   Ms.    Abigail         J.
# 351               413         SC          0   Mr.       Adam        NaN
# 984              1679         VC          0   Mr.       Adam         J.
# 562               835         SC          0   Sr.     Adrian        NaN
# 538               787         SC          0   Ms.      Aidan        NaN
# 835              1381         SC          0   Mr.       Ajay        NaN
# 406               523         SC          0   Mr.       Alan        NaN
# 894              1499         VC          0   Ms.       Alan         L.
# 224               225         EM          0   NaN       Alan          J
# 903              1517         VC          0   Mr.     Albert        NaN
# 986              1683         VC          0   Mr.     Albert         A.
# 342               395         SC          0   Mr.    Alberto         F.
# 605               921         SC          0   Ms.     Aldeen         J.
# 861              1433         SC          0   Mr.  Alejandro        NaN
# 192               193         EM          0   NaN  Alejandro          E
# 913              1537         VC          0   Mr.       Alex        NaN
# 162               163         EM          0   NaN       Alex          M
# 535               781         SC          0   Mr.  Alexander         J.
# 376               463         SC          0   Mr.  Alexander         J.
# 495               701         SC          0   Ms.      Alice        NaN
# 755              1221         SC          0   Ms.      Alice         L.
# 108               109         EM          0   NaN      Alice          O
# 959              1629         VC          0   NaN       Alma         B.
# 532               775         SC          0   Sr.     Alvaro        NaN
# 915              1541         VC          0   Mr.       Amir         T.
# 286               287         SP          0   NaN        Amy          E
# 306               323         SC          0   Ms.        Amy         E.
# 512               735         SC          0   Ms.        Amy         R.
# 379               469         SC          0   NaN    Andreas        NaN
# 213               214         EM          0   NaN    Andreas          T
# 474               659         SC          0   Mr.     Andrew        NaN
# 551               813         SC          0   Mr.     Andrew        NaN
# 46                 47         EM          0   NaN     Andrew          R
# 767              1245         SC          0   Mr.     Andrew         P.
# 683              1077         SC          0   Mr.     Andrew         R.
# 163               164         EM          0   NaN     Andrew          M
# 464               639         SC          0   Mr.       Andy        NaN
# 148               149         EM          0   NaN       Andy          M
# 345               401         SC          0   Ms.     Angela        NaN
# 114               115         EM          0   NaN     Angela          W
# 136               137         EM          0   NaN     Anibal          T
# 820              1351         SC          0   Ms.      Anita         R.
# 580               871         SC          0   Ms.        Ann         R.
# 363               437         SC          0   Ms.        Ann        NaN
# 661              1033         SC          0   Ms.        Ann         T.
# 307               325         SC          0   Ms.       Anna         A.
# 259               260         EM          0   NaN    Annette          L
#
#                    LastName Suffix  EmailPromotion
# 797                Leonetti    NaN               2
# 221                  Wright    NaN               0
# 508                     Con    NaN               0
# 632                Gonzalez    NaN               0
# 351                    Barr    NaN               1
# 984                Reynolds    Jr.               1
# 562              Dumitrascu    NaN               0
# 538                 Delaney    NaN               0
# 835             Manchepalli    NaN               0
# 406                  Brewer    NaN               1
# 894                 Monitor    NaN               0
# 224                  Brewer    NaN               0
# 903                  Mungin    NaN               1
# 986                  Rhodes    NaN               0
# 342                Baltazar    NaN               0
# 605               Gallagher    NaN               2
# 861                  McGuel    NaN               0
# 192                  McGuel    NaN               0
# 913                 Nayberg    NaN               0
# 162                 Nayberg    NaN               1
# 535                 Deborde    NaN               0
# 376                  Berger     II               1
# 495                   Clark    NaN               1
# 755               Kesterson    NaN               0
# 108                   Ciccu    NaN               1
# 959               Poorbaugh    NaN               0
# 532  De Matos Miranda Filho    NaN               1
# 915                    Netz    NaN               0
# 286                 Alberts    NaN               1
# 306                 Alberts    NaN               1
# 512              Consentino    NaN               0
# 379                Berglund    NaN               0
# 213                Berglund    NaN               0
# 474                 Cencini    NaN               0
# 551                   Dixon    NaN               0
# 46                     Hill    NaN               1
# 767              Kobylinski    NaN               0
# 683                    Hill    NaN               0
# 163                 Cencini    NaN               0
# 464               Carothers    NaN               0
# 148                    Ruth    NaN               1
# 345               Barbariol    NaN               0
# 114               Barbariol    NaN               2
# 136                   Sousa    NaN               0
# 820                 Lucerne    NaN               1
# 580                   Evans    NaN               1
# 363                   Beebe    NaN               0
# 661                    Hass    NaN               2
# 307                Albright    NaN               1
# 259                    Hill    NaN               1

# %% [markdown]
# Observe também que nenhuma atrbuição foi feita no nosso objeto "dados", pois não houve nenhuma atribuição a ele.

# %%
dados.head()
# veja que os dados originais permanecem inalterados
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion
# 0     Sánchez    NaN               0
# 1       Duffy    NaN               1
# 2  Tamburello    NaN               0
# 3     Walters    NaN               0
# 4    Erickson    NaN               0

# %% [markdown]
# Entretanto, há uma entrada de nome "**inplace**" que, quando ela recebe o valor lógico verdadeiro, por mais que nenhuma atribuição direta esteja sendo feita a "dados", os registros serão modificados no objeto original.

# %%
dados.sort_values("FirstName", inplace = True)
# podemos usar o inplace para modificar os dados no objeto que está sendo trabalhado

# %%
dados
# observe que os dados originais foram modificados e, agora, a ordenação dos usuários não se dá mais pelo
# índice, mas sim pelo campo de dados "First Name"
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
# ..                ...        ...        ...   ...       ...        ...
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# 216               217         EM          0   NaN    Zainal          T
# 101               102         EM          0   NaN     Zheng          W
# 901              1513         VC          0   Mr.     Zheng        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1
# ..        ...    ...             ...
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# 216    Arifin    NaN               1
# 101        Mu    NaN               0
# 901        Mu    NaN               0
#
# [1000 rows x 9 columns]

# %%
dados = pd.read_excel("Dados.xlsx")
# atribundo o banco de dados armazenado no arquivo "Dados.xlsx" ao nosso objeto novamente para que ele 
# retorne com os dados originais

# %%
dados
# observando que os dados originais permanecem inalterados e a ordenação dos usuários segue com referência 
# ao índice
# Out:
#      BusinessEntityID PersonType  NameStyle Title  FirstName MiddleName  \
# 0                   1         EM          0   NaN        Ken          J
# 1                   2         EM          0   NaN      Terri        Lee
# 2                   3         EM          0   NaN    Roberto        NaN
# 3                   4         EM          0   NaN        Rob        NaN
# 4                   5         EM          0   Ms.       Gail          A
# ..                ...        ...        ...   ...        ...        ...
# 995              1700         IN          0   Ms.    Rebecca         A.
# 996              1701         IN          0   Ms.    Dorothy         B.
# 997              1702         IN          0   Ms.  Carol Ann         F.
# 998              1703         IN          0   Mr.      Scott         M.
# 999              1704         IN          0   Mr.        Jim        NaN
#
#        LastName Suffix  EmailPromotion
# 0       Sánchez    NaN               0
# 1         Duffy    NaN               1
# 2    Tamburello    NaN               0
# 3       Walters    NaN               0
# 4      Erickson    NaN               0
# ..          ...    ...             ...
# 995    Robinson    NaN               0
# 996    Robinson    NaN               2
# 997      Rockne    NaN               0
# 998     Rodgers    NaN               0
# 999      Rodman    NaN               0
#
# [1000 rows x 9 columns]

# %% [markdown]
# Como foi citado acima, é possível fazer uma ordenação seguindo a ordem de mais de um campo de dados. Vale a pena salientar que o primeiro campo da entrada no atributo "sort_values" terá mais relevância em relação a segunda entrada.

# %%
dados.sort_values(["FirstName", "LastName"])
# usando o "sort_values" para fazer uma ordenação com base em mais de um campo de dados. No exemplo acima,
# "FirstName" terá mais relevância que "LastName"
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
# ..                ...        ...        ...   ...       ...        ...
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# 216               217         EM          0   NaN    Zainal          T
# 101               102         EM          0   NaN     Zheng          W
# 901              1513         VC          0   Mr.     Zheng        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1
# ..        ...    ...             ...
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# 216    Arifin    NaN               1
# 101        Mu    NaN               0
# 901        Mu    NaN               0
#
# [1000 rows x 9 columns]

# %% [markdown]
# Usando na entrada do atributo "sort_values" a propriedade "**ascending**", podemos delimitar se a ordenação será em ordem crescente ou decrescente, independente se o tipo de variável é numérica ou categórica.

# %%
dados.sort_values("FirstName", ascending = True)
# usando a propiedade "ascending" no atributo "sort_values" para indicar se a ordenação e crescente ou 
# decrescente usando valores lógicos. No exemplo acima, indicamos que a ordenação possuirá como referência
# o campo de dados "FirstName" de forma ascendente
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 351               413         SC          0   Mr.      Adam        NaN
# ..                ...        ...        ...   ...       ...        ...
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# 216               217         EM          0   NaN    Zainal          T
# 101               102         EM          0   NaN     Zheng          W
# 901              1513         VC          0   Mr.     Zheng        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 351      Barr    NaN               1
# ..        ...    ...             ...
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# 216    Arifin    NaN               1
# 101        Mu    NaN               0
# 901        Mu    NaN               0
#
# [1000 rows x 9 columns]

# %%
dados.sort_values("FirstName", ascending = False)
# usando a propiedade "ascending" no atributo "sort_values" para indicar se a ordenação e crescente ou 
# decrescente usando valores lógicos. No exemplo acima, indicamos que a ordenação possuirá como referência
# o campo de dados "FirstName" de forma não ascendente
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 901              1513         VC          0   Mr.     Zheng        NaN
# 101               102         EM          0   NaN     Zheng          W
# 216               217         EM          0   NaN    Zainal          T
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# ..                ...        ...        ...   ...       ...        ...
# 351               413         SC          0   Mr.      Adam        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 508               727         SC          0   Mr.     Aaron        NaN
# 221               222         EM          0   NaN  A. Scott        NaN
# 797              1305         SC          0   NaN        A.  Francesca
#
#      LastName Suffix  EmailPromotion
# 901        Mu    NaN               0
# 101        Mu    NaN               0
# 216    Arifin    NaN               1
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# ..        ...    ...             ...
# 351      Barr    NaN               1
# 632  Gonzalez    NaN               0
# 508       Con    NaN               0
# 221    Wright    NaN               0
# 797  Leonetti    NaN               2
#
# [1000 rows x 9 columns]

# %% [markdown]
# Podemos também escolher a se a ordenação será ascendente ou descendente com base em mais de um campo de dados. Lembrando que a relevância de ordenação sempre será do primeiro campo informado.

# %%
dados.sort_values(["FirstName", "LastName"], ascending = [True, False])
# usando a propiedade "ascending" no atributo "sort_values" para indicar se a ordenação e crescente ou 
# decrescente usando valores lógicos. No exemplo acima, indicamos que a ordenação possuirá como referência
# os campos de dados "FirstName" e "LastName", com respectivas relevâncias, sendo que "FirstName" será 
# ordenado de forma ascendente e "LastName" será ordenado de forma não ascendente. Para fazer isso, será
# usado uma lista de vetores dentro de outra lista
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 984              1679         VC          0   Mr.      Adam         J.
# ..                ...        ...        ...   ...       ...        ...
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# 216               217         EM          0   NaN    Zainal          T
# 101               102         EM          0   NaN     Zheng          W
# 901              1513         VC          0   Mr.     Zheng        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 984  Reynolds    Jr.               1
# ..        ...    ...             ...
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# 216    Arifin    NaN               1
# 101        Mu    NaN               0
# 901        Mu    NaN               0
#
# [1000 rows x 9 columns]

# %% [markdown]
# Lembre-se que a escolha de boas variáveis além de ser uma boa prática de programação, é uma forma de tornar o código mais claro. Observe abaixo as três linhas de código escritas. Elas possuem a mesma finalidade que as linhas anteriores. Entretanto, são mais fáceis de entender.

# %%
# criando uma lista que faz referência ao nome dos campos de dados do dataframe
colunas = ["FirstName", "LastName"]
# criando uma lista de valores lógicos que fazem referência ao tipo de ordenação ascendente dos respectivos
# campos de dados
ordenacao = [True, False]
# usando o atributo "sort_values" com as entradas fazendo uso das listas inicializadas acima
dados.sort_values(colunas, ascending = ordenacao)
# Out:
#      BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 797              1305         SC          0   NaN        A.  Francesca
# 221               222         EM          0   NaN  A. Scott        NaN
# 508               727         SC          0   Mr.     Aaron        NaN
# 632               975         SC          0   Ms.   Abigail         J.
# 984              1679         VC          0   Mr.      Adam         J.
# ..                ...        ...        ...   ...       ...        ...
# 186               187         EM          0   NaN    Yvonne          S
# 862              1435         SC          0   Ms.    Yvonne        NaN
# 216               217         EM          0   NaN    Zainal          T
# 101               102         EM          0   NaN     Zheng          W
# 901              1513         VC          0   Mr.     Zheng        NaN
#
#      LastName Suffix  EmailPromotion
# 797  Leonetti    NaN               2
# 221    Wright    NaN               0
# 508       Con    NaN               0
# 632  Gonzalez    NaN               0
# 984  Reynolds    Jr.               1
# ..        ...    ...             ...
# 186     McKay    NaN               0
# 862     McKay    NaN               0
# 216    Arifin    NaN               1
# 101        Mu    NaN               0
# 901        Mu    NaN               0
#
# [1000 rows x 9 columns]

# %% [markdown]
# Observe que o resultado foi o mesmo.

# %% [markdown]
# Portanto, foi estudando o uso do atributo "**sort_values**", pertencente a biblioteca "Pandas", para fazer a ordenação de dados. Assim, enriquecemos ainda mais nossa capacidade de fazer pré-processamento de dados usando a linguagem de programação Python.

# %% [markdown]
# ### Alguma dúvida? Entre em contato comigo:

# %% [markdown]
# - [Me envie um e-mail](mailto:alyssonmachado388@gmail.com);
