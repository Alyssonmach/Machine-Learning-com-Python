# %% [markdown]
# # Clusterização com K-means
# #### Implementando o algoritmo k-means em uma base de dados de créditou usando mais dimensões.

# %%
# importando as bibliotecas do python
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# colocando os dados no objeto 'dataframe'
dataframe = pd.read_csv('credit_card_clients.csv', encoding = 'utf-8', sep = ',', header = 1)

# %%
# visualizando o objeto 'dataframe'
dataframe
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
# visualizando a dimensão do 'dataframe'
print(dataframe.shape)
# Out:
# (30000, 25)

# %%
# somando todas as dívidas em uma só coluna para melhor análise dos dados
dataframe['BILL_TOTAL'] = dataframe['BILL_AMT1'] + dataframe['BILL_AMT2'] + dataframe['BILL_AMT3']  
dataframe['BILL_TOTAL'] = dataframe['BILL_AMT4'] + dataframe['BILL_AMT5'] + dataframe['BILL_AMT6']

# %%
# visualizando o objeto 'dataframe'
dataframe
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0         -1  ...          0          0         0       689         0
# 1          0  ...       3455       3261         0      1000      1000
# 2          0  ...      14948      15549      1518      1500      1000
# 3          0  ...      28959      29547      2000      2019      1200
# 4          0  ...      19146      19131      2000     36681     10000
# ...      ...  ...        ...        ...       ...       ...       ...
# 29995      0  ...      31237      15980      8500     20000      5003
# 29996     -1  ...       5190          0      1837      3526      8998
# 29997     -1  ...      20582      19357         0         0     22000
# 29998      0  ...      11855      48944     85900      3409      1178
# 29999      0  ...      32428      15313      2078      1800      1430
#
#        PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month  BILL_TOTAL
# 0             0         0         0                           1           0
# 1          1000         0      2000                           1        9988
# 2          1000      1000      5000                           0       44828
# 3          1100      1069      1000                           0       86820
# 4          9000       689       679                           0       59217
# ...         ...       ...       ...                         ...         ...
# 29995      3047      5000      1000                           0      135221
# 29996       129         0         0                           0       14169
# 29997      4200      2000      3100                           1       60817
# 29998      1926     52964      1804                           1      113573
# 29999      1000      1000      1000                           1       84276
#
# [30000 rows x 26 columns]

# %%
# pegando todos os dados possíveis para clusterizar os clientes
x = dataframe.iloc[:, [1, 2, 3, 4, 5, 25]].values

# %%
# visualizando 'x'
print(x)
# Out:
# [[ 20000      2      2      1     24      0]
#  [120000      2      2      2     26   9988]
#  [ 90000      2      2      2     34  44828]
#  ...
#  [ 30000      1      2      2     37  60817]
#  [ 80000      1      3      1     41 113573]
#  [ 50000      1      2      1     46  84276]]

# %%
# visualizando a dimensão de x
print(x.shape)
# Out:
# (30000, 6)

# %%
# criando o objeto 'scaler'
scaler = StandardScaler()

# %%
# escalonando os atributos armazenados em 'x'
x = scaler.fit_transform(x)

# %%
# criando uma tupla para armazenar a distância média dos dados em relação ao centróide pelo Elbow Method
WCSS = []

# %%
# iterando os dados para analisar qual o valor de k clusters ideal
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, random_state = 0)
    kmeans.fit(x)
    # adiciona o valor da distância média dos dados em relação ao centróide
    WCSS.append(kmeans.inertia_)

# %%
# configurando o gráfico
plt.figure(figsize = (10, 5))
plt.title('Valor do WCSS para K Clusters')
plt.plot(range(1, 11), WCSS, color = 'green', label = 'WCSS')
plt.xlabel('K Clusters')
plt.ylabel('Valor do WCSS')
plt.legend()
plt.box(False)
plt.grid(True)

# %%
# visualizando os valores do 'WCSS'
print(WCSS)
# Out:
# [180000.0, 143654.58142153986, 123745.06196536752, 108653.49858935914, 95848.39618061851, 86996.55937125847, 80275.8411839725, 76113.97720713764, 72068.65866080327, 68895.78259666271]

# %% [markdown]
# Observando o gráfico, o valor ideal de clusters é k = 4.

# %%
# criando o clusterizados 'kmeans'
kmeans = KMeans(n_clusters = 4, random_state = 0)

# %%
# realizando o treinamento e a previsão com os dados escalonados 'x'
previsoes = kmeans.fit_predict(x)

# %% [markdown]
# Como estamos trabalhando com dimensões maiores, não é possível plotar o gráfico dos dadados. a análise deve ser feita cuidadosamente pelo comportamento da tabela de dados, sendo uma tarefa mais difícil.

# %%
# importando a biblioteca numpy do python
import numpy as np

# %%
# adicionando as previoes aos dados do 'dataframe' e armazenando em 'lista_clientes'
lista_clientes = np.column_stack((dataframe, previsoes))

# %%
# visualizando a lista de clientes 
lista_clientes
# Out:
# array([[     1,  20000,      2, ...,      1,      0,      1],
#        [     2, 120000,      2, ...,      1,   9988,      0],
#        [     3,  90000,      2, ...,      0,  44828,      0],
#        ...,
#        [ 29998,  30000,      1, ...,      1,  60817,      2],
#        [ 29999,  80000,      1, ...,      1, 113573,      1],
#        [ 30000,  50000,      1, ...,      1,  84276,      1]], dtype=int64)

# %%
# ordenando os dados da linha com as informações de 'previsoes'
lista_clientes = lista_clientes[lista_clientes[:, 26].argsort()]

# %%
# visualizando a lista de clientes com os dados de clusterização ordenados
lista_clientes
# Out:
# array([[  7483,  70000,      2, ...,      0, 118499,      0],
#        [  6876,  30000,      2, ...,      1,  85311,      0],
#        [ 22700,  20000,      2, ...,      1,  47832,      0],
#        ...,
#        [ 11842, 370000,      2, ...,      0, 661816,      3],
#        [ 11763, 500000,      1, ...,      0, 379972,      3],
#        [  5438, 240000,      2, ...,      0, 492067,      3]], dtype=int64)

# %% [markdown]
# ### Alguma Dúvida? Entre em Contato Comigo:

# %% [markdown]
# - [Me envie um e-mail](mailto:alysson.barbosa@ee.ufcg.edu.br);
